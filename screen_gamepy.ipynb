# %% [markdown]
# # introduction to GamePy- Screens

# %% [markdown]
# **you need to install gamepy package to your python first **
#
# Please note that for this tutorial, we are using the Python IDE- feel free to use any IDE you prefer, but you need to understand there might be a few things that need to be set up slightly differently.

# %%
pip install pygame

# %% [markdown]
# **Now you need to create a new module-- main.py
# This will be your main file- this can have any name you want, but I will keep it as the MAIN because it will help later when we create packages and other modules to import. It is just a conventional way of doing this.**
#
#
# **STEP 1**: Importing Pygame
# We will be importing the pygame module to start off with. We would also be initializing pygame into our program.
#
#
# The code for the same is shown below.

# %%
import pygame
from sys import exite
pygame.init()

# %% [markdown]
# pygame.init()
# initialize all imported pygame modules such as
#
# *   pygame.quit()
# *   pygame.get_init()
# *   raise pygame.error(message)
# *   display.set_mode()

# %% [markdown]
# The first step in implementing a game is to design and  creating environment or the main screen, and this is what we are going to do in this tutorial is to build a game window. keep in that this tutorial is building towards creating a **Snake Game**
#
# **STEP 2**: Creating a basic window

# %% [markdown]
# Here is a fun artichal  that walk you through the mind set of creating a game in 11 steps [link text](https://www.wikihow.com/Make-Computer-Games)

# %% [markdown]
# The next thing that is needed is to create variables to set the width and height of the game window. For now, let’s keep both width and height as 800 and 500 respectively.
#
# To create a window object using gasmepy we need to used a function named display. this function takes two int type argument. both need to be constants becuase you dont what them to be changing through your game.
# there is multible ways of doing this and I am going to show you two diffrent programming styles through out this tutorial.

# %%
screen= pygame.display.set_mode((800,500)) # This tells pygame to create a screen with a width of 800 pixels and a height of 500 pixels. 
#If you run the program a window should flash on the screen briefly. 
#Try changing the height and width to various values and see how it effects the resulting window.

# %% [markdown]
# Remember when we said we want this to be constant- then we can define constants and pass them to the function instead of passing the numbers. This habit in programming will make your life a lot easier when the game grows, and code becomes harder to debug.

# %%
SCREEN_WIDTH= 800 # we should create constants module and save all these constant in. 
SCREEN_HIGHT=500
screen= pygame.display.set_mode((SCREEN_WIDTH,SCREEN_HIGHT))

# %% [markdown]
# Now windows or displays in pygame are called surfaces. Any component that will be displayed on the monitor will have its own surface; this is how pygame deals with objects, games, backgrounds, enemies etc.
# There are two types of surfaces.
# * The main surface is the main blank window -- environment.
# * The regular surface and is any thing displayed in the game
# both are created in the same manner

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There are a few things we can add to our main display, such as captions and it is done as follows

# %%
pygame.display.set_caption('My Sanke Game')

# %% [markdown]
# by defualt all object and surfeces colors is balck - but we have the fill() function to chamnge that

# %%
  screen.fill((255, 255, 255)) # Fill the background with white

# %% [markdown]
# the next part we need to concider something that is very important: that is the frame rate: how fast our game runs. we want to have same performance regardless of the speed of the computer the games is using.
#
# ![image.png](data:image/png;base64,...)
#
# This function is used to create a clock object which can be used to keep track of time. The various methods of clock object are below:
#
# **tick():**This method should be called once per frame. It will compute how many milliseconds have passed since the previous call. If you pass the optional framerate argument the function will delay to keep the game running slower than the given ticks per second. For example if we pass 10 as argument the program will never run at more than 10 frames per second.
#
# **get_time()**:It is used to obtain a number of milliseconds used between two tick()
#
# **get_fps()**:it gives information regarding the clock frame rate. it returns the output in floating-point value.

# %%
clock = pygame.time.Clock() # our animation speed is domentated by how fast we update our frames- in this case we want to keep it  constant

# %% [markdown]
#  Keep in mind you can break the ceiling, not the floor-- by this, we mean you can tell your computer to run your code at a lower rate than it can cover, but you can not tell it to run it at a higher rate than it can handle. For the above code to do anything, we need to add it to the game loop--- what is the game loop you asked? This is what we are going to disscuss below:

# %% [markdown]
# To be able to test and display our window, we need to creat something called a game loop ----- *what is the best type of iteration you think we should use and why?*
# to answer this quiestion we need to learn what is game loop-- SO, Game Loop is the loop that keeps the game running. It keeps running till the user wants to exit. While the game loop is running it mainly does the following tasks: Update our game window to show visual changes.
# this means we need a condition and this condition needs to be TRUE through out the runing of the game.
#
# *The following code will have two ways of doing the same thing as usual *

# %% [markdown]
# To add the background image all we need to do is use the function named image. load and add the path of the image as the parameter. We will also be sizing the image to make sure it fully fills up the whole screen.

# %%
while True:
    for event in pygame.event.get():
        # any thing that is added here will be excuted as long as the while condition is TRUE

CONDITION= TRUE
while CONDITION:
    for event in pygame.event.get():
              # any thing that is added here will be excuted as long as the while condition is TRUE

# %% [markdown]
# Within the fore loop, we will be able to create display updates and end our game. ending the game is very important and that can happen using the QUIT() function.
# We will end the game at this stage by clicking the X on the top right corner of the main window.
# so the updated game loop will be as follwos

# %%
CONDITION= TRUE
while CONDITION:
    for event in pygame.event.get():
      if event.type== pygame.QUIT:
        pygame.quit() # we are doing the oppiste of pygame.init()
        exit() # this is important to exit the while true loop on the spot and this is the most secured way of doing this. this method is built in python
  
    pygame.display.update()  # we need to update the window every time a change happens
    clock.tick(60) # here is where we set our clock rates : this means that this while loop should not run over 60 f/s - this is max we dont have to worry about min

# %% [markdown]
# Now let us add objects to our game: by this, I mean let us add a regular surface- this is going to be an object on the main screen to display something on our main window. We will not go deep on this because this will be the main topic for the next post.
#
# this is what we have now -- empty canvas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We need to create posted notes, and if we place enough on the display surface at the end, we should get something nice.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# all what we are going to do is to add a rectanular shape to our display
# we are going to add new surface and we will fill it with color
#
# fill Surface with a solid color
# fill(color, rect=None, special_flags=0) -> Rect
# Fill the Surface with a solid color. If no rect argument is given the entire Surface will be filled. The rect argument will limit the fill to a specific area. The fill will also be contained by the Surface clip area.
#
# The color argument can be either a RGB sequence, a RGBA sequence or a mapped color index. If using RGBA, the Alpha (A part of RGBA) is ignored unless the surface uses per pixel alpha (Surface has the SRCALPHA flag).
#
# New in pygame 1.8: Optional special_flags: BLEND_ADD, BLEND_SUB, BLEND_MULT, BLEND_MIN, BLEND_MAX.
#
# New in pygame 1.8.1: Optional special_flags: BLEND_RGBA_ADD, BLEND_RGBA_SUB, BLEND_RGBA_MULT, BLEND_RGBA_MIN, BLEND_RGBA_MAX BLEND_RGB_ADD, BLEND_RGB_SUB, BLEND_RGB_MULT, BLEND_RGB_MIN, BLEND_RGB_MAX.
#
# This will return the affected Surface area.

# %%
test_surface= pygame.surface(100,200)
test_surface.fill('Red')

# %% [markdown]
# To display the above surface, we need to add it to the game loop. now notice the (0,0) coordinate s and also make a not that in your test surface, we re placing the top left-hand side corner on the specific coordinate

# %%
screen.blit(test_surface,(0,0))# this code needs to be in the game loop within the for loop

# %% [markdown]
# now lwt us add text to our surface; first we need to creat a font surface then we need to add it to out game loop.
# we need to set up some attributes to the font method we are going to use

# %%
test_font= pggame.font.Font(none, 50) # the none means we are usig the defult font, and the 50 indicates the size 

# this is the test surface
Text_surface= test_font.render('my game',Fales,'Green')
# the following code goes in to the game loop within the for loop
screen.blit(test_surface,(300,50))

# %% [markdown]
# now the final thing we are goign to do is to add images to the dispaly surface.
# the files need to be in the same directory- it make it easier.
# we first will create a surface and import the files to the new surface, then we will blit in the game loop

# %%
# thi bit goes before the game loop
sky_surface= pygame.image.load(images/sky.png)
ground_surface= pygame.image.load(images/ground.png)

# the following code goes in to the main loop

screen.blit(sky_surface,(0,0))
screen.blit(ground_surface,(0,300))
